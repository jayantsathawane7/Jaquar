# %%
import json
import codecs
intents = json.load(codecs.open('jaquar_intentsss.json', 'r', 'utf-8-sig'))

x,y = [],[]
for intent in intents["intents"]:
    patterns = set(intent["pattern"])
    for pattern in patterns:
        x.append(pattern.lower().strip())
        y.append(intent["tag"].lower().strip())

import pandas as pd
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df = pd.DataFrame({"text":x,"labels":y})
df['labels'] = le.fit_transform(df['labels'])
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#                   text  labels
# 0               saunas       2
# 1          i thank you      38
# 2     good bye for now      15
# 3  i want to know more      17
# 4          linear flex      34

# %%
# df.to_csv('jaquar_intents.csv', index=False)

# %%
from datasets import Dataset
dataset = Dataset.from_pandas(df)

# %%
number_of_labels = len(le.classes_)
number_of_labels
# Out:
# 42

# %%
id2label = {i:label for i,label in enumerate(le.classes_)}
label2id = {label:i for i,label in id2label.items()}

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-distilroberta-v1')
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)

tokenized_classifier = dataset.map(preprocess_function, batched=True)

tokenized_classifier.set_format("torch",columns=["input_ids", "attention_mask", "labels"])

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

from torch.utils.data import DataLoader

train_dataloader = DataLoader(
    tokenized_classifier, shuffle=True, batch_size=2, collate_fn=data_collator
)

# %%
for x in train_dataloader:
    print(x)
    break

# %%
from transformers.modeling_outputs import SequenceClassifierOutput
from torch.nn import CrossEntropyLoss
import torch.utils.checkpoint
import torch.nn as nn
import torch
from transformers import AutoTokenizer, AutoConfig, RobertaModel, RobertaPreTrainedModel


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class IntentClassifier(RobertaPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)

        self.roberta = RobertaModel.from_pretrained(
            'sentence-transformers/all-distilroberta-v1') #, add_pooling_layer=False
        for param in self.roberta.parameters():
            param.requires_grad = False

        self.pre_classifier = nn.Linear(config.hidden_size, config.hidden_size)
        self.dropout = nn.Dropout(0.5)
        self.classifier = nn.Linear(config.hidden_size, config.num_classes)


    def mean_pooling(self, model_output, attention_mask):
        token_embeddings = model_output[0]
        input_mask_expanded = attention_mask.unsqueeze(
            -1).expand(token_embeddings.size()).float()
        return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

    def forward(self,input_ids=None,attention_mask=None,labels=None):
        output = self.roberta(input_ids=input_ids,attention_mask=attention_mask)
        pooler = self.mean_pooling(output, attention_mask)
        # pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        logits = self.classifier(pooler)

        loss = None
        if labels is not None:
            loss_fct = CrossEntropyLoss()
            loss = loss_fct(logits, labels)

        return SequenceClassifierOutput(
            loss=loss,
            logits=logits,
        )

# %%
config = AutoConfig.from_pretrained("j-hartmann/emotion-english-distilroberta-base")
del config._name_or_path
config.id2label= id2label
config.label2id= label2id
config.num_classes = number_of_labels
config

# %%
model = IntentClassifier(config).to('cuda')

# %%
from torch.optim import AdamW

def calcuate_accu(big_idx, targets):
    n_correct = (big_idx==targets).sum().item()
    return n_correct


optimizer = AdamW(model.parameters(), lr=5e-5)
EPOCHS = 50

def train(epoch, model, dataloader):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    
    for _,data in enumerate(dataloader, 0):

        input_ids = data['input_ids'].to(device)
        attention_mask = data['attention_mask'].to(device)
        labels = data['labels'].to(device)

        outputs = model(input_ids, attention_mask, labels)
        loss = outputs['loss']

        tr_loss += loss.item()
        big_val, big_idx = torch.max(outputs.logits, dim=1)
        n_correct += calcuate_accu(big_idx, labels)

        nb_tr_steps += 1
        nb_tr_examples+=labels.size(0)
        
        loss.backward() 
        optimizer.step()
        optimizer.zero_grad()

    print(f'The Total Accuracy for Epoch {epoch}: {(n_correct*100)/nb_tr_examples}')
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss Epoch: {epoch_loss}")
    print(f"Training Accuracy Epoch: {epoch_accu}")

# %%
model.train()
for epoch in range(EPOCHS):
    train(epoch,model,dataloader=train_dataloader)
model.eval()

# %%
from torch.nn.functional import softmax

texts = df['text'].to_list()
labels = df['labels'].to_list()

for text,label in zip(texts,labels):
    tokens = tokenizer(text, padding=True, truncation=True, return_tensors='pt', return_attention_mask=True)
    with torch.no_grad():
        output = model(**tokens.to(device))
        scores = softmax(output[0], dim=1)[0].detach().cpu().numpy()
        # if scores.argmax()!=label:
        #     print(text, scores.max()*100)
        print(text.center(50), id2label[scores.argmax()].center(30),"-",id2label[label].center(30), scores.max()*100)

# %%
from torch.nn.functional import softmax
text = "prime nu"

encoded_input = tokenizer(text, return_tensors='pt')
encoded_input = encoded_input.to('cuda')
output = model(**encoded_input.to('cuda'))
scores = softmax(output[0], dim=1)[0].detach().cpu().numpy()
labels[scores.argmax()], scores.max()
print(text.center(30), id2label[scores.argmax()].center(30), scores.max()*100)

# %%
model.save_pretrained('./JaquarIntentClassification')
tokenizer.save_pretrained('./JaquarIntentClassification')

# %%
from transformers import AutoTokenizer
intent_tokenizer = AutoTokenizer.from_pretrained('JaquarIntentClassification')
intent_model = IntentClassifier.from_pretrained('JaquarIntentClassification').to('cuda')

# %%
from torch.nn.functional import softmax

texts = df['text'].to_list()
labels = df['labels'].to_list()

for text,label in zip(texts,labels):
    tokens = intent_tokenizer(text, padding=True, truncation=True, return_tensors='pt', return_attention_mask=True)
    with torch.no_grad():
        output = intent_model(**tokens.to(device))
        scores = softmax(output[0], dim=1)[0].detach().cpu().numpy()
        print(text.center(50), id2label[scores.argmax()].center(30),"-",id2label[label].center(30), scores.max()*100)
# Out:
#                       saunas                             bathroom_products        -       bathroom_products        99.58343505859375
#                    i thank you                                thankyou            -            thankyou            99.98900890350342
#                  good bye for now                               exit              -              exit              99.99876022338867
#                i want to know more                              faq               -              faq               93.45238208770752
#                    linear flex                         professional_lighting      -     professional_lighting      98.90550374984741
#                  guardrail lights                      professional_lighting      -     professional_lighting      98.78140687942505
#                       hellio                                  welcome             -            welcome             99.9842643737793
#                very good thank you                            thankyou            -            thankyou            99.98124241828918
#                   thank you sara                              thankyou            -            thankyou            99.83987212181091
#                      hey bot!                                 welcome             -            welcome             99.99682903289795
#                    wall washer                         professional_lighting      -     professional_lighting      96.14350199699402
#            am i chatting with a human?                     bot_challenge          -         bot_challenge          99.99784231185913
#                  hey, let's talk                              welcome             -            welcome             99.99314546585083
#                     greetings                                 welcome             -            welcome             99.98418092727661
#                     main menu                                main_menu            -           main_menu            99.97573494911194
#                   great, thanks                               thankyou            -            thankyou            99.99598264694214
#           thanks a bunch for everything                       thankyou            -            thankyou            99.99101161956787
#                  facebook account                             facebook            -            facebook            99.13269877433777
#                      good by                                    exit              -              exit              99.76797699928284
#                        bye!                                     exit              -              exit              99.99823570251465
#                      toodles                                    exit              -              exit              98.52399826049805
#                     thanks you                                thankyou            -            thankyou            99.99788999557495
#                    thanks again                               thankyou            -            thankyou            99.97996687889099
#                 plan your bathroom                       bathroom_products        -       bathroom_products        99.24681782722473
#                      lighting                            lighting_products        -       lighting_products        96.60942554473877
#               i suppose you're real                        bot_challenge          -         bot_challenge          99.97661709785461
#                 lighting products                        lighting_products        -       lighting_products        99.2723286151886
#                   ta ta for now                                 exit              -              exit              99.7148334980011
#               you are a real person                        bot_challenge          -         bot_challenge          99.9653697013855
#                     contractor                              professional          -          professional          99.81271624565125
#                 that's all for now                              exit              -              exit              99.50461387634277
#                  bye bye see you                                exit              -              exit              99.99991655349731
#                   linkedin page                               linkedin            -            linkedin            99.78086352348328
#                       see ya                                    exit              -              exit              99.99786615371704
#                   ground burials                       professional_lighting      -     professional_lighting      98.73272776603699
#                      hey dude                                 welcome             -            welcome             99.99755620956421
#                  steam solutions                         bathroom_products        -       bathroom_products        99.90319013595581
#                     whirlpools                           bathroom_products        -       bathroom_products        99.65294003486633
#                professional_service                     professional_service      -      professional_service      93.38919520378113
#       are led light bulbs worth the money??                   faq_set             -            faq_set             99.18069243431091
#                         ty                                    thankyou            -            thankyou            99.99817609786987
#           visit our social media handles                    social_media          -          social_media          97.04181551933289
#                    hey there..                                welcome             -            welcome             99.99927282333374
#                  customer support                         customer_service        -        customer_service        97.04297184944153
#                    bye for now                                  exit              -              exit              99.99939203262329
# what do you mean by jaquar complete bathing solutions?            faq_set             -            faq_set             98.51802587509155
#               hello is anybody there                          welcome             -            welcome             99.95525479316711
#                        helo                                   welcome             -            welcome             99.99796152114868
#                   you are a bot                            bot_challenge          -         bot_challenge          99.99170303344727
#             i want to provide feedback                        feedback            -            feedback            99.88390803337097
#                        hi !                                   welcome             -            welcome             99.99992847442627
#                  is this a human?                          bot_challenge          -         bot_challenge          99.96881484985352
#                       hello!                                  welcome             -            welcome             99.9998688697815
#                    sanitaryware                          bathroom_products        -       bathroom_products        99.84184503555298
#                      hey hey                                  welcome             -            welcome             99.99994039535522
#             thanks this is great news                         thankyou            -            thankyou            99.9579131603241
#                    social_media                             social_media          -          social_media          98.2320249080658
#                     ok goodbye                                  exit              -              exit              99.99909400939941
#                     hello bot                                 welcome             -            welcome             99.95821118354797
#            are you a chatbot or human?                     bot_challenge          -         bot_challenge          99.99568462371826
#                    google play                              google_play           -          google_play           99.24479722976685
#                     good bye.                                   exit              -              exit              99.99890327453613
#                  hello sweatheart                             welcome             -            welcome             99.9959945678711
#                 are you artificial                         bot_challenge          -         bot_challenge          99.99072551727295
#                professional service                     professional_service      -      professional_service      97.44259715080261
#                 bathroom products                        bathroom_products        -       bathroom_products        99.93669390678406
#                    cad_drawings                             cad_drawings          -          cad_drawings          99.7142493724823
#                   human or bot?                            bot_challenge          -         bot_challenge          99.95315074920654
#              you're a bot aren't you?                      bot_challenge          -         bot_challenge          99.93957281112671
#                       leave                                     exit              -              exit              99.63436722755432
#              call purchase assistant                  call_purchase_assistant     -    call_purchase_assistant     99.41672086715698
#                       halloo                                  welcome             -            welcome             99.99372959136963
#                      bye then                                   exit              -              exit              99.99868869781494
#                  dealer_location                          dealer_location         -        dealer_location         99.60457682609558
#                      hellooo                                  welcome             -            welcome             99.99783039093018
#                      retailer                               professional          -          professional          96.51361107826233
#                    thanks love                                thankyou            -            thankyou            99.92320537567139
#            download customer catalogue              download_customer_catalogue   -  download_customer_catalogue   96.77714109420776
#                     start menu                               main_menu            -           main_menu            99.65657591819763
#             locate the nearest dealer                     dealer_location         -        dealer_location         99.73365664482117
#                    good thanks                                thankyou            -            thankyou            99.9980092048645
#          download professional catalogue           download_professional_catalogue - download_professional_catalogue 93.31759810447693
#                i guess you're real                         bot_challenge          -         bot_challenge          99.95774626731873
#                       jojojo                                  welcome             -            welcome             99.86609220504761
#                   cool thank you                              thankyou            -            thankyou            99.99802112579346
#                      okay bye                                   exit              -              exit              99.99773502349854
#                       hell9o                                  welcome             -            welcome             99.96473789215088
#                     hi friend                                 welcome             -            welcome             99.99781847000122
#                   alright thanks                              thankyou            -            thankyou            99.96104836463928
#                   cee you later                                 exit              -              exit              99.9879240989685
#                     google app                              google_play           -          google_play           98.97144436836243
#                    social media                             social_media          -          social_media          99.19955730438232
#                  are you a robot?                          bot_challenge          -         bot_challenge          99.99923706054688
#               new bathroom products                      bathroom_products        -       bathroom_products        99.94124174118042
#                      helloooo                                 welcome             -            welcome             99.9984860420227
#          are you artificial intelligence                   bot_challenge          -         bot_challenge          99.99682903289795
#             professional_service_form                professional_service_form    -   professional_service_form    92.90364384651184
#                   initial point                              main_menu            -           main_menu            99.48800802230835
#                     led bulbs                            consumer_lighting        -       consumer_lighting        99.57889914512634
#                   bot or human?                            bot_challenge          -         bot_challenge          99.94542002677917
#                      plumber                                professional          -          professional          99.75292086601257
#                center_virtual_tour                      center_virtual_tour       -      center_virtual_tour       99.68820810317993
#                bathroom accessories                      bathroom_products        -       bathroom_products        99.8746395111084
#                      end chat                                   exit              -              exit              99.99798536300659
#                 that's appreciated                            thankyou            -            thankyou            99.84733462333679
#                  youtube account                              youtube             -            youtube             99.3051290512085
#                        hiii                                   welcome             -            welcome             99.99315738677979
#               professional_lighting                    professional_lighting      -     professional_lighting      93.2703971862793
#              am i speaking to an ai?                       bot_challenge          -         bot_challenge          99.96968507766724
#                    youtube page                               youtube             -            youtube             99.0358293056488
#            thanks for your information                        thankyou            -            thankyou            99.98243451118469
#                  are you virtual?                          bot_challenge          -         bot_challenge          99.9925971031189
#                        hi!                                    welcome             -            welcome             99.99994039535522
#              download our mobile app                        download_app          -          download_app          95.67657113075256
#                       ok thx                                  thankyou            -            thankyou            99.99194145202637
#                   previous menu                            previous_menu          -         previous_menu          98.72653484344482
#                        hola                                   welcome             -            welcome             99.90200996398926
#                      see you                                    exit              -              exit              99.99940395355225
#               thank you and good bye                          thankyou            -            thankyou            94.55705285072327
#                  flexi wallwasher                      professional_lighting      -     professional_lighting      98.11590909957886
#                     hallo sara                                welcome             -            welcome             99.89185333251953
#              how can i give feedback                          feedback            -            feedback            99.7277319431305
#                    flood lights                        professional_lighting      -     professional_lighting      98.52685332298279
#                  linkedin account                             linkedin            -            linkedin            99.76063966751099
#                   are you real?                            bot_challenge          -         bot_challenge          99.99778270721436
#                    see you soon                                 exit              -              exit              99.97614026069641
#                   are you a bot?                           bot_challenge          -         bot_challenge          99.99939203262329
#                       hallo                                   welcome             -            welcome             99.99836683273315
#                  go to main menu                             main_menu            -           main_menu            99.91231560707092
#                      linkedin                                 linkedin            -            linkedin            99.8115062713623
#                  you are not fake                          bot_challenge          -         bot_challenge          99.99581575393677
#             show me lighting products                    lighting_products        -       lighting_products        98.391854763031
#                        hi'                                    welcome             -            welcome             99.9995231628418
#                   ok thanks sara                              thankyou            -            thankyou            99.8736560344696
#                   other queries                            other_queries          -         other_queries          99.82940554618835
#                        byee                                     exit              -              exit              99.8595654964447
#                       sleep!                                    exit              -              exit              99.76957440376282
#                  great thank you                              thankyou            -            thankyou            99.99967813491821
#                       hello                                   welcome             -            welcome             99.99935626983643
#                hello it is me again                           welcome             -            welcome             99.94767308235168
#                        hey                                    welcome             -            welcome             99.99951124191284
#                   leave me alone                                exit              -              exit              99.73570704460144
#                        cya                                      exit              -              exit              99.51527118682861
#                      faucets                             bathroom_products        -       bathroom_products        99.9466598033905
#                  flushing systems                        bathroom_products        -       bathroom_products        99.72129464149475
#                      hi, bot                                  welcome             -            welcome             99.98038411140442
#                    bye bye bot                                  exit              -              exit              99.83389377593994
#                      thankyou                                 thankyou            -            thankyou            99.99815225601196
#                  product_3d_view                          product_3d_view         -        product_3d_view         99.41651225090027
#               jaguar lighting dealer                      dealer_location         -        dealer_location         99.65710639953613
#                      bonjour                                  welcome             -            welcome             98.88200163841248
#                   hellllooooooo                               welcome             -            welcome             99.99833106994629
#                    thanks a lot                               thankyou            -            thankyou            99.99964237213135
#                   see you later                                 exit              -              exit              99.99964237213135
#               are you a real person?                       bot_challenge          -         bot_challenge          99.99852180480957
#                are you a real bot?                         bot_challenge          -         bot_challenge          99.99942779541016
#                   facebook page                               facebook            -            facebook            99.02620911598206
#                   see you around                                exit              -              exit              99.98565912246704
#                  i appreciate it                              thankyou            -            thankyou            99.94996786117554
#                        cad                                  cad_drawings          -          cad_drawings          99.91440773010254
#                        heyo                                   welcome             -            welcome             99.99306201934814
#                 thank you so much                             thankyou            -            thankyou            99.9985933303833
#                    download_app                             download_app          -          download_app          95.40602564811707
#                      farewell                                   exit              -              exit              99.75119829177856
#                    cad drawings                             cad_drawings          -          cad_drawings          99.87592697143555
#               new bathroom arrivals                      bathroom_products        -       bathroom_products        99.82174038887024
#                 thank you anyways                             thankyou            -            thankyou            99.68414306640625
#                    new_arrivals                             new_arrivals          -          new_arrivals          97.14547395706177
#                    fine for now                                 exit              -              exit              99.55227375030518
#  how to avoid slipping danger from the bathroom?              faq_set             -            faq_set             97.775399684906
#        i'm obviously talking to a computer                 bot_challenge          -         bot_challenge          99.54890608787537
#                       ok bye                                    exit              -              exit              99.99958276748657
#                     app store                                app_store            -           app_store            98.7803041934967
#                     architect                               professional          -          professional          99.98028874397278
#                   feedback exit                            feedback_exit          -         feedback_exit          99.26982522010803
#                      hi again                                 welcome             -            welcome             99.99744892120361
#                   instagram page                             instagram            -           instagram            99.45868253707886
#                      sayonara                                   exit              -              exit              95.28099298477173
#                     take care                                   exit              -              exit              96.69241905212402
#                     consultant                              professional          -          professional          99.64295029640198
#          are you sure that you're a bot?                   bot_challenge          -         bot_challenge          99.96219873428345
#                  goodbye for now                                exit              -              exit              99.99587535858154
#                      hello hi                                 welcome             -            welcome             99.99998807907104
#                  hello everybody                              welcome             -            welcome             99.97621178627014
#             frequently asked questions                          faq               -              faq               99.54724907875061
#                   previous_menu                            previous_menu          -         previous_menu          99.67137575149536
#                        halo                                   welcome             -            welcome             99.84812140464783
#                 catalogue_download                       catalogue_download       -       catalogue_download       94.96586322784424
#                    cool. thanks                               thankyou            -            thankyou            99.98574256896973
#                   after_redirect                           after_redirect         -         after_redirect         98.31660985946655
#                      youtube                                  youtube             -            youtube             99.26378726959229
#                 installation_video                       installation_video       -       installation_video       99.74383115768433
#                     led panels                           consumer_lighting        -       consumer_lighting        99.90100860595703
#                      thank's!                                 thankyou            -            thankyou            99.99569654464722
#                      ok, bye                                    exit              -              exit              99.99948740005493
#                       howdy                                   welcome             -            welcome             99.97281432151794
#                   is this a bot?                           bot_challenge          -         bot_challenge          99.99792575836182
#                   you can go now                                exit              -              exit              99.34338331222534
#                 perfect thank you                             thankyou            -            thankyou            99.99756813049316
#                 are you a program                          bot_challenge          -         bot_challenge          99.95158910751343
#                  are you a human?                          bot_challenge          -         bot_challenge          99.99847412109375
#                 are you a chatbot?                         bot_challenge          -         bot_challenge          99.99878406524658
#                     ok thanks                                 thankyou            -            thankyou            99.86240863800049
#                      hi pal!                                  welcome             -            welcome             99.99995231628418
#                   led downlights                         consumer_lighting        -       consumer_lighting        98.93181920051575
#                are you a rasa bot?                         bot_challenge          -         bot_challenge          99.94988441467285
#                who am i talking to?                        bot_challenge          -         bot_challenge          99.67482089996338
#                 terrific thank you                            thankyou            -            thankyou            99.99134540557861
#                   are you a bot                            bot_challenge          -         bot_challenge          99.9995231628418
#                    hello buddy                                welcome             -            welcome             99.99909400939941
#                        yoo                                    welcome             -            welcome             99.75409507751465
#                    hello there                                welcome             -            welcome             99.99481439590454
#                thermostatic mixers                       bathroom_products        -       bathroom_products        99.65537786483765
#                   are you robot                            bot_challenge          -         bot_challenge          99.99960660934448
#                      good bye                                   exit              -              exit              99.99967813491821
#                  hello sweet boy                              welcome             -            welcome             99.99278783798218
#                        bulb                              lighting_products        -       lighting_products        98.99405837059021
#                     konichiwa                                 welcome             -            welcome             99.24185276031494
#                      twitter                                  twitter             -            twitter             99.23852682113647
#                        thx                                    thankyou            -            thankyou            99.99951124191284
#                     time to go                                  exit              -              exit              99.88276362419128
#                  led spot lights                         consumer_lighting        -       consumer_lighting        99.65742826461792
#                thanks for the help                            thankyou            -            thankyou            99.97909665107727
#                   thanks bye bye                                exit              -              exit              99.91766810417175
#                well hello there ;)                            welcome             -            welcome             99.99630451202393
#                      hang up                                    exit              -              exit              99.67254400253296
#                        thnx                                   thankyou            -            thankyou            99.99960660934448
#                    hello world                                welcome             -            welcome             99.9995470046997
#                       thanks                                  thankyou            -            thankyou            99.99699592590332
#                   oh thats good!                              thankyou            -            thankyou            99.5457649230957
#                  well....goodbye.                               exit              -              exit              99.91495609283447
#                    thanks buddy                               thankyou            -            thankyou            99.98950958251953
#             you helped a lot thank you                        thankyou            -            thankyou            99.99220371246338
#                  product 3d view                          product_3d_view         -        product_3d_view         99.6807336807251
#                        bye                                      exit              -              exit              99.99918937683105
#                lighting consultant                          professional          -          professional          99.47927594184875
#                      thank u                                  thankyou            -            thankyou            99.99674558639526
#                   are you human?                           bot_challenge          -         bot_challenge          99.99960660934448
#                   well thank you                              thankyou            -            thankyou            99.99643564224243
#                  awesome service                              thankyou            -            thankyou            99.94176626205444
#                  you are so real                           bot_challenge          -         bot_challenge          99.92706179618835
#                     are you ai                             bot_challenge          -         bot_challenge          99.97572302818298
#                 bathroom_products                        bathroom_products        -       bathroom_products        99.68562126159668
#                       heyho                                   welcome             -            welcome             99.9998688697815
#                       adios                                     exit              -              exit              99.59321618080139
#                bye bye see you soon                             exit              -              exit              99.99905824661255
#                    google_play                              google_play           -          google_play           98.73937368392944
#    what are the best light bulbs for enclosure                faq_set             -            faq_set             99.24973249435425
#                 download catalogue                       catalogue_download       -       catalogue_download       92.19239354133606
#                   thank you, bye                                exit              -              exit              98.5967218875885
#                       heelio                                  welcome             -            welcome             99.91459846496582
#                      showers                             bathroom_products        -       bathroom_products        99.99169111251831
#                   you're a robot                           bot_challenge          -         bot_challenge          99.98214840888977
#                  twitter account                              twitter             -            twitter             99.31060671806335
#                 installation video                       installation_video       -       installation_video       99.85238909721375
#                         hi                                    welcome             -            welcome             99.99990463256836
#        view orientation center virtual tour             center_virtual_tour       -      center_virtual_tour       99.84928369522095
#                     thanks bot                                thankyou            -            thankyou            99.90895986557007
#                     ok thanks!                                thankyou            -            thankyou            99.65135455131531
#                  spot projectors                       professional_lighting      -     professional_lighting      99.28998947143555
#                  close this talk                                exit              -              exit              99.71039891242981
#                     i gotta go                                  exit              -              exit              99.0644097328186
#              appreciate all the help                          thankyou            -            thankyou            99.99399185180664
#                      hi folks                                 welcome             -            welcome             99.99568462371826
#                      thanks!                                  thankyou            -            thankyou            99.99715089797974
#                       ciao.                                     exit              -              exit              99.18040037155151
#                        hi,                                    welcome             -            welcome             99.99654293060303
#             youtube video installation                   installation_video       -       installation_video       98.95297884941101
#                      bathroom                            bathroom_products        -       bathroom_products        99.87026453018188
#         hello, my name is charles pfeffer                     welcome             -            welcome             99.82870221138
#                   see you . bye                                 exit              -              exit              99.99997615814209
#                 catalogue download                       catalogue_download       -       catalogue_download       98.51147532463074
#                   linear lights                        professional_lighting      -     professional_lighting      98.49591851234436
#                       thnaks                                  thankyou            -            thankyou            99.69018697738647
#                 are you a chatbot                          bot_challenge          -         bot_challenge          99.99969005584717
#                  hi there it's me                             welcome             -            welcome             99.99908208847046
#                       thanx                                   thankyou            -            thankyou            99.99773502349854
#          orientation center virtual tour                center_virtual_tour       -      center_virtual_tour       99.81213212013245
#            bye was nice talking to you                          exit              -              exit              99.50022101402283
#                    hello friend                               welcome             -            welcome             99.99587535858154
#             thank you that will be all                        thankyou            -            thankyou            99.89209175109863
#               am i talking to a bot?                       bot_challenge          -         bot_challenge          99.99743700027466
#                    electricians                             professional          -          professional          99.79698061943054
#                  amazing, thanks                              thankyou            -            thankyou            99.98177886009216
#                       ok.bye                                    exit              -              exit              99.95954632759094
#                      ey boss                                  welcome             -            welcome             99.92145299911499
#                    are you real                            bot_challenge          -         bot_challenge          99.99915361404419
#               goodbye see you later                             exit              -              exit              99.99963045120239
#                    great thanks                               thankyou            -            thankyou            99.99794960021973
#                  thank you again                              thankyou            -            thankyou            99.98407363891602
# where do i get jaquar orientation center addresses? or how can i locate jaquar orientation centres?            faq_set             -            faq_set             99.51509237289429
#                 lighting_products                        lighting_products        -       lighting_products        98.89063835144043
#                  thanks for that                              thankyou            -            thankyou            99.88589286804199
#                   hey there boy                               welcome             -            welcome             99.99967813491821
#                      hey ther                                 welcome             -            welcome             99.99887943267822
#                      feedback                                 feedback            -            feedback            98.05928468704224
#                     chat later                                  exit              -              exit              99.95763897895813
#                      then bye                                   exit              -              exit              99.9995470046997
#                   hey let's talk                              welcome             -            welcome             99.99450445175171
#                       bye!!                                     exit              -              exit              99.9955415725708
#                     yes thanks                                thankyou            -            thankyou            99.91656541824341
#                     later you                                   exit              -              exit              99.99735355377197
#                  customer_service                         customer_service        -        customer_service        98.51255416870117
#              thank you for your help                          thankyou            -            thankyou            99.9815046787262
#            download_customer_catalogue              download_customer_catalogue   -  download_customer_catalogue   91.96460843086243
# cool. thank you. i really like what you're doing.             thankyou            -            thankyou            99.53670501708984
#                 are you just a bot                         bot_challenge          -         bot_challenge          99.99964237213135
#                      hiihihi                                  welcome             -            welcome             99.90039467811584
#               i appreciate your help                          thankyou            -            thankyou            99.97722506523132
#            i want to share my opinions                        feedback            -            feedback            98.75184893608093
#               professional lighting                    professional_lighting      -     professional_lighting      96.26365303993225
#              customer service contact                     customer_service        -        customer_service        99.22939538955688
#                 am i taking to bot                         bot_challenge          -         bot_challenge          99.9682068824768
#                      go back                               previous_menu          -         previous_menu          97.96469211578369
#             i said, helllllloooooo!!!!                        welcome             -            welcome             99.77467656135559
#                  much appreciated                             thankyou            -            thankyou            99.97894167900085
#                    well thanks                                thankyou            -            thankyou            99.99216794967651
#                   i see, thanks                               thankyou            -            thankyou            99.85028505325317
#                       heylo                                   welcome             -            welcome             99.99394416809082
#               you're a human, right?                       bot_challenge          -         bot_challenge          99.94847774505615
#                are you really a bot                        bot_challenge          -         bot_challenge          99.99942779541016
#                      hi there                                 welcome             -            welcome             99.9998688697815
#                 bye bye take care                               exit              -              exit              99.99955892562866
#                       helleo                                  welcome             -            welcome             99.8357355594635
#           i want to share my experience                       feedback            -            feedback            99.6077835559845
#              go back to previous menu                      previous_menu          -         previous_menu          98.2151985168457
#                   window lights                        professional_lighting      -     professional_lighting      98.89795780181885
#                     cheers bro                                thankyou            -            thankyou            99.99690055847168
#                are you a real human                        bot_challenge          -         bot_challenge          99.99985694885254
#                 you are a chatbot                          bot_challenge          -         bot_challenge          99.99544620513916
#                  led strip lights                        consumer_lighting        -       consumer_lighting        99.80302453041077
#                       go awy                                    exit              -              exit              99.5705783367157
#                      gotta go                                   exit              -              exit              99.93374943733215
#             professional service form                professional_service_form    -   professional_service_form    97.07245230674744
#                        byr                                      exit              -              exit              99.4073212146759
#        can led lighting harm our eyesight?                    faq_set             -            faq_set             98.60799908638
#                    you are real                            bot_challenge          -         bot_challenge          99.99585151672363
#                 thx for your help                             thankyou            -            thankyou            99.99974966049194
#                  ok goodbye then                                exit              -              exit              99.99178647994995
#                  you are not real                          bot_challenge          -         bot_challenge          99.99767541885376
#                thanks for your help                           thankyou            -            thankyou            99.98390674591064
#                  dealer location                          dealer_location         -        dealer_location         99.9281108379364
#                  shower enclosure                        bathroom_products        -       bathroom_products        99.73410964012146
#                thanks for the help!                           thankyou            -            thankyou            99.94303584098816
#                  i said goodbye!                                exit              -              exit              99.96589422225952
#       i want to share my experience with you                  feedback            -            feedback            99.34281706809998
#                    twitter page                               twitter             -            twitter             99.43739175796509
#                    under water                         professional_lighting      -     professional_lighting      97.48218059539795
#               hi im amanda anderson                           welcome             -            welcome             99.10241365432739
#                      halloooo                                 welcome             -            welcome             99.99936819076538
#                  you're a chatbot                          bot_challenge          -         bot_challenge          99.98546838760376
#                 consumer lighting                        consumer_lighting        -       consumer_lighting        98.1620192527771
#                        tnx                                    thankyou            -            thankyou            99.98947381973267
#                    cool, thanks                               thankyou            -            thankyou            99.96111989021301
#                    new arrivals                             new_arrivals          -          new_arrivals          98.94630312919617
#                    alright bye                                  exit              -              exit              99.99778270721436
#                  catch you later                                exit              -              exit              99.996018409729
#                   jaguar dealer                           dealer_location         -        dealer_location         99.7343122959137
#                    see u later                                  exit              -              exit              99.9995470046997
#                  aren't you a bot                          bot_challenge          -         bot_challenge          99.99675750732422
#                   labour_service                           labour_service         -         labour_service         90.63869714736938
#                  you are chatbot                           bot_challenge          -         bot_challenge          99.97846484184265
#                      goodbye.                                   exit              -              exit              99.99622106552124
#                       thnks                                   thankyou            -            thankyou            99.99949932098389
#                     bath tubs                            bathroom_products        -       bathroom_products        99.99412298202515
#                  i am a customer                              customer            -            customer            97.07133769989014
#               are you a real human?                        bot_challenge          -         bot_challenge          99.99949932098389
#                      goodbye!                                   exit              -              exit              99.99159574508667
#             show me bathroom products                    bathroom_products        -       bathroom_products        99.88722205162048
#                 instagram account                            instagram            -           instagram            99.61989521980286
#                   okay thank you                              thankyou            -            thankyou            99.87670183181763
#                   what are you?                            bot_challenge          -         bot_challenge          99.97517466545105
#                       bye .                                     exit              -              exit              99.99415874481201
#                 interior designer                           professional          -          professional          99.91577863693237
#                   water heaters                          bathroom_products        -       bathroom_products        99.85356330871582
#                       hi hi                                   welcome             -            welcome             100.0
#                     thanks bye                                  exit              -              exit              99.8350739479065
#                   appreciate it                               thankyou            -            thankyou            99.79110360145569
#                       hi man                                  welcome             -            welcome             99.99972581863403
#                      bye-bye                                    exit              -              exit              99.98447895050049
#                     hey there                                 welcome             -            welcome             99.99978542327881
#                      bye bye                                    exit              -              exit              99.99966621398926
#                       light                              lighting_products        -       lighting_products        99.56923127174377
#                      facebook                                 facebook            -            facebook            97.93596267700195
#                    much thanks                                thankyou            -            thankyou            99.99709129333496
#                  customer service                         customer_service        -        customer_service        98.01287055015564
#                       heeey                                   welcome             -            welcome             99.9917984008789
#                  hieeeeeeeeeeeee                              welcome             -            welcome             99.94986057281494
#                 you are very real                          bot_challenge          -         bot_challenge          99.99499320983887
#                 newsletter updates                          professional          -          professional          99.05322790145874
#                appreciate your help                           thankyou            -            thankyou            99.97734427452087
#                      customer                                 customer            -            customer            94.82179284095764
#                    generate boq                             professional          -          professional          99.07968044281006
#                      cheerio                                    exit              -              exit              97.79595136642456
#                    hello robot                                welcome             -            welcome             99.93257522583008
#                    apple store                               app_store            -           app_store            99.84210729598999
#                   are you an ai?                           bot_challenge          -         bot_challenge          99.76400136947632
#                        spas                              bathroom_products        -       bathroom_products        99.67206120491028
#                 alright thank you                             thankyou            -            thankyou            99.98443126678467
#                       hieee                                   welcome             -            welcome             99.9454915523529
#                     dot lights                         professional_lighting      -     professional_lighting      97.14265465736389
#                       hello?                                  welcome             -            welcome             99.99370574951172
#                    who are you?                            bot_challenge          -         bot_challenge          99.512380361557
#                go to previous menu                         previous_menu          -         previous_menu          98.71323108673096
#                     thank you                                 thankyou            -            thankyou            99.99852180480957
#                 tlak to you later                               exit              -              exit              99.29341077804565
#                   other_queries                            other_queries          -         other_queries          99.45666790008545
#                       hi bot                                  welcome             -            welcome             99.98654127120972
#                thank you my friend                            thankyou            -            thankyou            99.9996542930603
#                       lights                             lighting_products        -       lighting_products        97.35547304153442
#                    many thanks                                thankyou            -            thankyou            99.99841451644897
#                        hi?                                    welcome             -            welcome             99.9977707862854
#                   shower panels                          bathroom_products        -       bathroom_products        99.97850060462952
#                labour service form                      labour_service_form       -      labour_service_form       95.80678343772888
#          download_professional_catalogue           download_professional_catalogue - download_professional_catalogue 83.83128643035889
#                what is pms and pmc?                           faq_set             -            faq_set             96.02609276771545
#                      ios app                                 app_store            -           app_store            96.38684391975403
#         am i talking to an actual person?                  bot_challenge          -         bot_challenge          99.99487400054932
#                  linear inground                       professional_lighting      -     professional_lighting      99.71761703491211
#                      hey bot                                  welcome             -            welcome             99.99663829803467
#              hi i'm sandra hernandez                          welcome             -            welcome             99.69808459281921
#                i am a professional                          professional          -          professional          98.28603863716125
#                    cool thanks                                thankyou            -            thankyou            99.9834656715393
#                      bye bye                                    exit              -              exit              99.99966621398926
#                end the conversation                             exit              -              exit              99.9699354171753
#                   labour service                           labour_service         -         labour_service         95.38567066192627
#                 led street lights                        consumer_lighting        -       consumer_lighting        99.85268115997314
#                  amazing service                              thankyou            -            thankyou            99.86806511878967
#                     apple app                                app_store            -           app_store            95.33775448799133
#                   feedback_exit                            feedback_exit          -         feedback_exit          99.13017153739929
#                       greet                                   welcome             -            welcome             99.76773858070374
#                        heya                                   welcome             -            welcome             99.99594688415527
#                     hi mister                                 welcome             -            welcome             99.99974966049194
#               are you a real person                        bot_challenge          -         bot_challenge          99.9991774559021
#                    professional                             professional          -          professional          96.57784700393677
#                 consumer_lighting                        consumer_lighting        -       consumer_lighting        98.8538920879364
#                    android app                              google_play           -          google_play           95.03859281539917
#                        ciao                                     exit              -              exit              99.6699869632721
#                        hei                                    welcome             -            welcome             99.98410940170288
#                     hey, sara!                                welcome             -            welcome             99.98231530189514
#                      hi sara                                  welcome             -            welcome             99.98825788497925
#                     hi friends                                welcome             -            welcome             99.99204874038696
#                  why are you here                          bot_challenge          -         bot_challenge          98.93695116043091
#                     instagram                                instagram            -           instagram            99.77079629898071
#                  trunking lights                       professional_lighting      -     professional_lighting      97.27330803871155
#             are you a human or a bot?                      bot_challenge          -         bot_challenge          99.99475479125977
#                go back to main menu                          main_menu            -           main_menu            98.93125891685486
#                i think you are real                        bot_challenge          -         bot_challenge          99.99668598175049
#              call_purchase_assistant                  call_purchase_assistant     -    call_purchase_assistant     98.87054562568665
#                     hi.......                                 welcome             -            welcome             99.9993085861206
#                    led battens                           consumer_lighting        -       consumer_lighting        99.7438907623291
# can we buy the products from jaquar orientation centre?            faq_set             -            faq_set             99.59568381309509
#                   thanks so much                              thankyou            -            thankyou            99.99943971633911
#                        hii                                    welcome             -            welcome             99.98332262039185
#                      bye bot                                    exit              -              exit              99.82615113258362
#              am i talking to a human?                      bot_challenge          -         bot_challenge          99.99818801879883
#                  are you a robot                           bot_challenge          -         bot_challenge          99.9997615814209
#                         yo                                    welcome             -            welcome             99.9166488647461
#                      goodbye                                    exit              -              exit              99.9974250793457
#                      builder                                professional          -          professional          99.7984528541565
#            are you even a real person?                     bot_challenge          -         bot_challenge          99.98800754547119
#                   nice thank you                              thankyou            -            thankyou            99.99912977218628
#                        hlo                                    welcome             -            welcome             99.97667670249939
#                labour_service_form                      labour_service_form       -      labour_service_form       94.59803104400635
#                     main_menu                                main_menu            -           main_menu            99.88215565681458
#                        faq                                      faq               -              faq               99.55182671546936
#                        exit                                     exit              -              exit              98.68260025978088
